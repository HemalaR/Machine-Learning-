# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\mlalgorithm\canada.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
sns.regplot(x='year',y='per capita income (US$)',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='per capita income (US$)'>

# %%
x=df.drop('per capita income (US$)',axis=1)

# %%
y=df.drop('year',axis=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
brain=LinearRegression()

# %%
brain.fit(x,y)
# Out:
# LinearRegression()

# %%
brain.score(x,y)
# Out:
# 0.890916917957032

# %%
brain.predict([[2025]])
# Out:
# C:\Users\HEMALA\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[45431.01947053]])

# %%
#prepare a linear regression model to predict gdp growth of canadian government using the given data
